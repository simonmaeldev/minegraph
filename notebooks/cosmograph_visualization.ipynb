# %% [markdown]
# # Minecraft Transformation Graph - Cosmograph Visualization
#
# This notebook provides an interactive, GPU-accelerated visualization of Minecraft item transformations using [Cosmograph](https://cosmograph.app/), a high-performance graph visualization widget.
#
# ## Prerequisites
#
# Make sure you've installed the required dependencies:
# ```bash
# uv add cosmograph jupyter

# %% [markdown]
# ## Setup & Data Loading <a id="setup"></a>
#
# First, let's import the required libraries and load our transformation data.

# %%
# Standard library imports
import sys
from pathlib import Path

# Third-party imports
import pandas as pd
from cosmograph import Cosmograph

import networkx as nx
import logging

# Suppress verbose logging
logging.getLogger('src.graph_utils').setLevel(logging.WARNING)
logging.getLogger('src.analyze_graph').setLevel(logging.WARNING)

# Add src directory to path for imports
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# Import our data preparation utilities
from src.utils.cosmograph_data_prep import prepare_cosmograph_data

print("✓ All imports successful!")
print(f"✓ Project root: {project_root}")
# Out:
# ✓ All imports successful!
# ✓ Project root: /home/apprentyr/projects/minegraph

# %%
# Define file paths
#csv_path = str(project_root / "output" / "transformations.csv")
csv_path = str(project_root / "output" / "transformations.csv")
config_path = str(project_root / "config" / "graph_colors.txt")
# filter_link ['bartering', 'brewing', 'composting', 'crafting', 'mob_drop', 'smelting', 'smithing', 'stonecutter', 'trading']

# Prepare data for Cosmograph
print("Preparing data for visualization...\n")
points, links, color_config = prepare_cosmograph_data(
    #csv_path = str(project_root / "output" / "technical_transformations.csv"), 
    csv_path = str(project_root / "output" / "transformations.csv"), 
    config_path = str(project_root / "config" / "graph_colors.txt"),
    only_main_component = False,
    #filter_link = ['brewing', 'composting', 'crafting', 'mob_drop', 'smelting', 'smithing', 'stonecutter'], 
    include_intermediate_nodes = True,
    #starting_nodes = ['Fox'],
    #exploration = 'child' # 'parent', 'child', 'both'
)


# Create the Cosmograph visualization
graph = Cosmograph(
    # Data
    points=points,
    links=links,
    
    # Point (node) configuration
    point_id_by='id',
    point_label_by='label',
    point_size_by='size',
    point_color_by='color',
    
    # Link (edge) configuration
    link_source_by='source',
    link_target_by='target',
    link_color_by='color',
    link_arrows=True,  # Show directional arrows
    link_width=1.5,
    #link_arrows_size_scale=2,
    
    # Label settings
    show_hovered_point_label=True,  # Show label when hovering
    show_top_labels=True,  # Always show labels for important nodes
    show_top_labels_limit=50,  # Number of top labels to show
    
    # Visual appearance
    background_color='#1a1a1a',  # Dark background
    point_size_scale=0.5,  # Scale up node sizes for visibility
    scale_points_on_zoom=True,  # Keep nodes visible when zooming
    render_links=True,
    
    # Force simulation parameters
    simulation_repulsion=0.5,  # How much nodes push apart
    simulation_link_spring=0.8,  # How strongly edges pull nodes together
    simulation_link_distance=20,  # Ideal edge length
    simulation_friction=0.8,  # Slow down movement over time
    simulation_decay=1500,  # How long simulation runs (ms)
)

print("🎨 Rendering graph visualization...")
print("   (This may take a few moments for large graphs)\n")

# Display the graph
graph
# Out:
# Preparing data for visualization...
#
# INFO - Starting Cosmograph data preparation...
# INFO - Loaded 12 color mappings from /home/apprentyr/projects/minegraph/config/graph_colors.txt
# INFO - Loaded 2421 transformations from /home/apprentyr/projects/minegraph/output/transformations.csv
# INFO - Built points DataFrame: 1347 items + 1136 intermediate nodes
# INFO - Built links DataFrame: 5376 edges
# INFO - Calculated node sizes based on connectivity
# INFO - Data preparation complete!
# INFO -   Total nodes: 2483 (1347 items + 1136 intermediate)
# INFO -   Total edges: 5376
# 🎨 Rendering graph visualization...
#    (This may take a few moments for large graphs)

# %% [markdown]
# ## Filtering Examples <a id="filtering"></a>
#
# You can create filtered views of the graph by subsetting the data. This is useful for exploring specific transformation types or item chains.

# %% [markdown]
# ### Filter 1: Show Only Crafting Transformations

# %% [markdown]
# ### Filter 2: Show Diamond-Related Items

# %%
# Find all nodes related to diamonds
diamond_items = points[points['label'].str.contains('Bone Meal', case=False, na=False)]['id'].tolist()

# Find all links connected to diamond items
diamond_links = links[
    links['source'].isin(diamond_items) | 
    links['target'].isin(diamond_items)
]

# Get all nodes involved
diamond_node_ids = set(diamond_links['source']).union(set(diamond_links['target']))
diamond_points = points[points['id'].isin(diamond_node_ids)]

print(diamond_links)

print(f"Diamond-related graph: {len(diamond_points)} nodes, {len(diamond_links)} edges")

graph_diamond = Cosmograph(
    points=diamond_points,
    links=diamond_links,
    point_id_by='id',
    point_label_by='label',
    point_size_by='size',
    point_color_by='color',
    link_source_by='source',
    link_target_by='target',
    link_color_by='color',
    link_arrows=True,
    link_arrows_size_scale = 2,
    background_color='#1a1a1a',
    show_hovered_point_label=True,
    show_top_labels=True,
)

# Uncomment to display:
graph_diamond
# Out:
#            source      target transformation_type    color  arrows
# 83          Wheat   Bone Meal          composting  #27AE60    True
# 86          Bread   Bone Meal          composting  #27AE60    True
# 87         Cookie   Bone Meal          composting  #27AE60    True
# 89       Hay Bale   Bone Meal          composting  #27AE60    True
# 95           Cake   Bone Meal          composting  #27AE60    True
# 96    Pumpkin Pie   Bone Meal          composting  #27AE60    True
# 198     Bone Meal  Bone Block            crafting  #4A90E2    True
# 1090   Bone Block   Bone Meal            crafting  #4A90E2    True
# 1118    Bone Meal         Dye            crafting  #4A90E2    True
# Diamond-related graph: 9 nodes, 9 edges

# %% [markdown]
# ### Filter 3: Custom Multi-Type Filter
#
# Combine multiple transformation types:

# %%
# Show only crafting, smelting, and smithing
selected_types = ['crafting', 'smelting', 'smithing']
filtered_links = links[links['transformation_type'].isin(selected_types)]

# Get all involved nodes
filtered_node_ids = set(filtered_links['source']).union(set(filtered_links['target']))
filtered_points = points[points['id'].isin(filtered_node_ids)]

print(f"Multi-type graph ({', '.join(selected_types)}):")
print(f"  {len(filtered_points)} nodes, {len(filtered_links)} edges")

# Uncomment to create and display:
# graph_multi = Cosmograph(
#     points=filtered_points,
#     links=filtered_links,
#     point_id_by='id',
#     point_label_by='label',
#     point_size_by='size',
#     point_color_by='color',
#     link_source_by='source',
#     link_target_by='target',
#     link_color_by='color',
#     link_arrows=True,
#     background_color='#1a1a1a',
#     show_hovered_point_label=True,
# )
# graph_multi

# %% [markdown]
# ## Export & Sharing <a id="export"></a>
#
# ### Saving the Notebook
#
# To save your work:
# 1. Use **File → Save** or press `Cmd+S` (Mac) / `Ctrl+S` (Windows/Linux)
# 2. The Cosmograph visualizations remain interactive in the saved notebook
#
# ### Exporting to HTML
#
# To share your visualization:
# 1. **File → Save and Export Notebook As → HTML**
# 2. The exported HTML file includes fully interactive Cosmograph widgets
# 3. Share the HTML file with colleagues or publish it online
#
# ### Taking Screenshots
#
# While Cosmograph doesn't have built-in screenshot functionality, you can:
# - Use your browser's screenshot tools
# - Use OS screenshot utilities (Cmd+Shift+4 on Mac, Win+Shift+S on Windows)
# - Right-click and "Save image as" (may vary by browser)

# %% [markdown]
# ## Recursive Parent Exploration
#
# This section allows you to explore all parent nodes (ingredients) of any item, recursively going back through the entire crafting chain.

# %%
# Load NetworkX graph for parent analysis
import networkx as nx
import logging

# Suppress verbose logging
logging.getLogger('src.graph_utils').setLevel(logging.WARNING)
logging.getLogger('src.analyze_graph').setLevel(logging.WARNING)

try:
    # Check if graph is already loaded
    _ = analysis_graph.number_of_nodes()
    print(f"✓ Using existing analysis graph: {analysis_graph.number_of_nodes()} nodes")
except NameError:
    # Load the analysis graph using existing csv_path and config_path from earlier cells
    from src.analyze_graph import load_graph
    
    print("Loading analysis graph for parent traversal...")
    analysis_graph = load_graph(
        csv_path=csv_path,  # Already defined in data preparation cell
        config_path=config_path  # Already defined in data preparation cell
    )
    print(f"✓ Graph loaded: {analysis_graph.number_of_nodes()} nodes, {analysis_graph.number_of_edges()} edges")
# Out:
# Loading analysis graph for parent traversal...
# INFO - Loaded 12 color mappings from /home/apprentyr/projects/minegraph/config/graph_colors.txt
# INFO - Loading analysis graph from /home/apprentyr/projects/minegraph/output/technical_transformations.csv
# INFO - Loaded 1068 transformations from /home/apprentyr/projects/minegraph/output/technical_transformations.csv
# INFO - Analysis graph contains 656 unique items
# INFO - Analysis graph contains 656 total nodes
# INFO - Analysis graph contains 1307 edges
# ✓ Graph loaded: 656 nodes, 1307 edges

# %%
# Function definitions for recursive parent exploration

def get_all_parents_recursive(node_name: str, graph: nx.DiGraph) -> dict:
    """
    Recursively find all parents (predecessors) of a node.
    
    Similar to add_score_parents in src/analyze_graph.py but returns all parents
    organized by depth level.
    
    Args:
        node_name: The item to find parents for
        graph: NetworkX directed graph
        
    Returns:
        Dictionary mapping parent nodes to their depth level:
        - 0 = direct parents (immediate inputs)
        - 1 = grandparents, etc.
    """
    parents_by_depth = {}
    visited = set()
    
    def traverse(current_node: str, depth: int):
        if current_node in visited:
            return
        visited.add(current_node)
        
        for parent in graph.predecessors(current_node):
            if parent not in parents_by_depth:
                parents_by_depth[parent] = depth
            traverse(parent, depth + 1)
    
    traverse(node_name, 0)
    return parents_by_depth


def create_parents_visualization(node_name: str, graph: nx.DiGraph, points_df, color_config):
    """
    Create a Cosmograph visualization showing all parents of a node.
    
    Args:
        node_name: The source node to visualize
        graph: NetworkX graph with all transformations
        points_df: DataFrame with node information from Cosmograph prep
        color_config: Dict mapping transformation types to colors
        
    Returns:
        Cosmograph widget with visualization
    """
    # Get all parents
    parents = get_all_parents_recursive(node_name, graph)
    
    if not parents:
        print(f"❌ No parents found for '{node_name}'")
        return None
    
    # Create subgraph with source node and all parents
    all_nodes = {node_name}
    all_nodes.update(parents.keys())
    subgraph = graph.subgraph(all_nodes).copy()
    
    # Build points for visualization
    vis_points = []
    for node in subgraph.nodes():
        is_source = (node == node_name)
        node_data_rows = points_df[points_df['id'] == node]
        
        if len(node_data_rows) > 0:
            node_data = node_data_rows.iloc[0].to_dict()
            # Make source node visually distinct (RED and LARGER)
            if is_source:
                node_data['color'] = '#FF6B6B'  # Bright red
                node_data['size'] = node_data['size'] * 2.0  # Much larger
        else:
            # Fallback for nodes not in DataFrame
            node_data = {
                'id': node,
                'label': node,
                'node_type': 'item',
                'size': 30 if is_source else 15,
                'color': '#FF6B6B' if is_source else '#FFFFFF'
            }
        vis_points.append(node_data)
    
    # Build links for visualization
    vis_links = []
    for source, target, data in subgraph.edges(data=True):
        vis_links.append({
            'source': source,
            'target': target,
            'transformation_type': data.get('transformation_type', 'unknown'),
            'color': color_config.get(data.get('transformation_type', 'unknown'), '#CCCCCC'),
            'arrows': True
        })
    
    # Create DataFrames
    vis_points_df = pd.DataFrame(vis_points)
    vis_links_df = pd.DataFrame(vis_links)
    
    # Create and return Cosmograph visualization
    return Cosmograph(
        points=vis_points_df,
        links=vis_links_df,
        point_id_by='id',
        point_label_by='label',
        point_size_by='size',
        point_color_by='color',
        link_source_by='source',
        link_target_by='target',
        link_color_by='color',
        link_arrows=True,
        background_color='#1a1a1a',
        show_hovered_point_label=True,
        show_top_labels=True,
        show_top_labels_limit=50,
        simulation_repulsion=0.8,
        simulation_link_distance=30,
    )

print("✓ Functions loaded!")
# Out:
# ✓ Functions loaded!

# %% [markdown]
# ### Explore Parents of Any Item
#
# Simply change the `node_to_explore` variable below to any item name, then run the cell to see:
# 1. A text summary of all parent nodes organized by depth
# 2. An interactive visualization with the source node highlighted in **RED**

# %%
# Set the item name you want to explore
node_to_explore = "Redstone Dust"  # ← Change this to any item name

# Get all parents recursively
parents = get_all_parents_recursive(node_to_explore, analysis_graph)

if not parents:
    print(f"❌ No parents found for '{node_to_explore}'")
    print(f"   This item might not exist or is a root item (no inputs)")
else:
    # Organize by depth level
    by_depth = {}
    for parent, depth in parents.items():
        if depth not in by_depth:
            by_depth[depth] = []
        by_depth[depth].append(parent)
    
    # Sort each depth level alphabetically
    for depth in by_depth:
        by_depth[depth].sort()
    
    # Print summary
    print(f"\n{'='*60}")
    print(f"  ALL PARENTS OF: {node_to_explore}")
    print(f"{'='*60}\n")
    print(f"🎯 Source Node: {node_to_explore} (shown in RED below)\n")
    
    for depth in sorted(by_depth.keys()):
        parents_at_depth = by_depth[depth]
        if depth == 0:
            print(f"📦 Direct Inputs (Depth {depth}): {len(parents_at_depth)} items")
        else:
            print(f"📦 Depth {depth} ({depth} {'step' if depth == 1 else 'steps'} back): {len(parents_at_depth)} items")
        
        # Show first 10 items, then summarize
        for i, parent in enumerate(parents_at_depth[:10], 1):
            print(f"   {i:3d}. {parent}")
        if len(parents_at_depth) > 10:
            print(f"   ... and {len(parents_at_depth) - 10} more items")
        print()
    
    print(f"{'='*60}")
    print(f"📊 Summary: {len(parents)} unique parent nodes across {max(by_depth.keys()) + 1} depth levels")
    print(f"{'='*60}\n")
    
    # Create and display the visualization
    print(f"🎨 Creating interactive visualization...")
    graph_viz = create_parents_visualization(node_to_explore, analysis_graph, points, color_config)
    
    if graph_viz:
        print(f"✓ Visualization ready!")
        print(f"🎯 RED node = {node_to_explore} (your source item)")
        print(f"⚪ WHITE nodes = Parent ingredients")
        print(f"➡️  Arrows show transformation direction\n")

# Display the graph (must be last line for Jupyter to render)
# Out:
# ...
#   ALL PARENTS OF: Redstone Dust
# ...
#
# 🎯 Source Node: Redstone Dust (shown in RED below)
#
# 📦 Direct Inputs (Depth 0): 4 items
#      1. Block of Redstone
#      2. Deepslate Redstone Ore
#      3. Emerald
#      4. Redstone Ore
#
# 📦 Depth 1 (1 step back): 49 items
#      1. Andesite
#      2. Beetroot
#      3. Block of Emerald
#      4. Boat
#      5. Book
#      6. Book and Quill
#      7. Carrot
#      8. Clay Ball
#      9. Coal
#     10. Compass
#    ... and 39 more items
#
# 📦 Depth 2 (2 steps back): 37 items
#      1. Block of Coal
#      2. Block of Diamond
#      3. Block of Iron
#      4. Breeze Rod
#      5. Cat
#      6. Coal Ore
#      7. Cobblestone
#      8. Cobweb
#      9. Deepslate Coal Ore
#     10. Deepslate Diamond Ore
#    ... and 27 more items
#
# 📦 Depth 3 (3 steps back): 47 items
#      1. Allium
#      2. Azure Bluet
#      3. Blaze Powder
#      4. Block of Raw Iron
#      5. Blue Orchid
#      6. Bone Meal
#      7. Brown Mushroom
#      8. Cactus Flower
# ...

# %%
graph_viz

# %%
# Explore children of multiple seeds
print("Exploring children (products) from multiple seeds: 'Stick' and 'Iron Ingot'...\n")
print("This finds everything that can be crafted from EITHER seed:\n")

points_seed, links_seed, config = prepare_cosmograph_data(
    csv_path,
    config_path,
    only_main_component=True,
    include_intermediate_nodes=False,
    starting_nodes=['Stick', 'Iron Ingot'],
    exploration='child'
)

# Count seed nodes
seed_nodes = points_seed[points_seed['color'] == '#FF0000']
print(f"✓ Found {len(points_seed)} product nodes, {len(links_seed)} edges")
print(f"✓ Red nodes: {list(seed_nodes['id'])}\n")

graph_multi_seed = Cosmograph(
    points=points_seed,
    links=links_seed,
    point_id_by='id',
    point_label_by='label',
    point_size_by='size',
    point_color_by='color',
    link_source_by='source',
    link_target_by='target',
    link_color_by='color',
    link_arrows=True,
    background_color='#1a1a1a',
    show_hovered_point_label=True,
    show_top_labels=True,
    show_top_labels_limit=30,
    simulation_repulsion=0.5,
    simulation_link_distance=25,
)

graph_multi_seed

# %% [markdown]
# ### Example 4: Multiple Seeds - Compare "Stick" and "Iron Ingot"
#
# Explore all products that can be made from multiple seed items (union of both explorations).

# %%
# Explore both directions from Planks
print("Exploring both directions from 'Planks'...\n")
print("This shows the complete neighborhood:")
print("  • Parents: Where planks come from (logs)")
print("  • Children: What can be crafted from planks\n")

points_seed, links_seed, config = prepare_cosmograph_data(
    csv_path,
    config_path,
    only_main_component=True,
    include_intermediate_nodes=False,
    starting_nodes=['Planks'],
    exploration='both'
)

print(f"✓ Found {len(points_seed)} nodes, {len(links_seed)} edges")
print(f"✓ Red node = Planks (seed)\n")

graph_planks = Cosmograph(
    points=points_seed,
    links=links_seed,
    point_id_by='id',
    point_label_by='label',
    point_size_by='size',
    point_color_by='color',
    link_source_by='source',
    link_target_by='target',
    link_color_by='color',
    link_arrows=True,
    background_color='#1a1a1a',
    show_hovered_point_label=True,
    show_top_labels=True,
    show_top_labels_limit=30,
    simulation_repulsion=0.5,
    simulation_link_distance=25,
)

graph_planks

# %% [markdown]
# ### Example 3: Explore Both Directions from "Planks"
#
# Find the complete transformation neighborhood around planks (both parents and children).

# %%
# Explore parents (ingredients) of Diamond Sword
print("Exploring parents (all ingredients needed for) 'Diamond Sword'...\n")

points_seed, links_seed, config = prepare_cosmograph_data(
    csv_path,
    config_path,
    only_main_component=True,
    include_intermediate_nodes=False,
    starting_nodes=['Diamond Sword'],
    exploration='parent'
)

print(f"✓ Found {len(points_seed)} ingredient nodes, {len(links_seed)} edges")
print(f"✓ Red node = Diamond Sword (seed)\n")

graph_diamond_sword = Cosmograph(
    points=points_seed,
    links=links_seed,
    point_id_by='id',
    point_label_by='label',
    point_size_by='size',
    point_color_by='color',
    link_source_by='source',
    link_target_by='target',
    link_color_by='color',
    link_arrows=True,
    background_color='#1a1a1a',
    show_hovered_point_label=True,
    show_top_labels=True,
    show_top_labels_limit=30,
    simulation_repulsion=0.5,
    simulation_link_distance=25,
)

graph_diamond_sword

# %% [markdown]
# ### Example 2: Explore Parents of "Diamond Sword"
#
# Find all ingredients needed to craft a diamond sword (upstream inputs).

# %%
# Explore children (downstream products) of Iron Ingot
print("Exploring children (products that can be made from) 'Iron Ingot'...\n")

points_seed, links_seed, config = prepare_cosmograph_data(
    csv_path,
    config_path,
    only_main_component=True,
    include_intermediate_nodes=False,
    starting_nodes=['Iron Ingot'],
    exploration='child'
)

print(f"✓ Found {len(points_seed)} reachable nodes, {len(links_seed)} edges")
print(f"✓ Red-colored nodes are seeds\n")

graph_iron_child = Cosmograph(
    points=points_seed,
    links=links_seed,
    point_id_by='id',
    point_label_by='label',
    point_size_by='size',
    point_color_by='color',
    link_source_by='source',
    link_target_by='target',
    link_color_by='color',
    link_arrows=True,
    background_color='#1a1a1a',
    show_hovered_point_label=True,
    show_top_labels=True,
    show_top_labels_limit=30,
    simulation_repulsion=0.5,
    simulation_link_distance=25,
)

graph_iron_child

# %% [markdown]
# ### Example 1: Explore Children of "Iron Ingot"
#
# Find all items that can be crafted FROM iron ingot (downstream products).

# %% [markdown]
# ## Seed-Based Subgraph Exploration
#
# This section demonstrates the new seed-based filtering feature, which allows you to extract and visualize subgraphs starting from specific seed items with configurable exploration direction.
#
# Seed nodes are colored in RED and made 2x larger for easy identification.
